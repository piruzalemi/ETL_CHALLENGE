# %%
import pandas as pd

# %%
history_price_df = pd.read_html('https://finance.yahoo.com/quote/SPY/history?p=SPY')[0]
history_price_df
# Out:
#                                                   Date  \
# 0                                         Jan 31, 2020
# 1                                         Jan 30, 2020
# 2                                         Jan 29, 2020
# 3                                         Jan 28, 2020
# 4                                         Jan 27, 2020
# ..                                                 ...
# 96                                        Sep 17, 2019
# 97                                        Sep 16, 2019
# 98                                        Sep 13, 2019
# 99                                        Sep 12, 2019
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                               327.00
# 1                                               324.36
# 2                                               328.38
# 3                                               325.06
# 4                                               323.03
# ..                                                 ...
# 96                                              299.94
# 97                                              299.84
# 98                                              301.78
# 99                                              301.25
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 0                                               327.17
# 1                                               327.91
# 2                                               328.63
# 3                                               327.85
# 4                                               325.12
# ..                                                 ...
# 96                                              301.02
# 97                                              301.14
# 98                                              302.17
# 99                                              302.46
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 0                                               320.73
# 1                                               323.54
# 2                                               326.40
# 3                                               323.60
# 4                                               322.66
# ..                                                 ...
# 96                                              299.75
# 97                                              299.45
# 98                                              300.68
# 99                                              300.41
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 0                                               321.73
# 1                                               327.68
# 2                                               326.62
# 3                                               326.89
# 4                                               323.50
# ..                                                 ...
# 96                                              300.92
# 97                                              300.16
# 98                                              301.09
# 99                                              301.29
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 0                                               321.73
# 1                                               327.68
# 2                                               326.62
# 3                                               326.89
# 4                                               323.50
# ..                                                 ...
# 96                                              298.07
# 97                                              297.32
# 98                                              298.24
# 99                                              298.44
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 0                                            113688600
# 1                                             75491800
# 2                                             53888900
# 3                                             63834000
# 4                                             84062500
# ..                                                 ...
# 96                                            41475500
# 97                                            58191200
# 98                                            62104800
# 99                                            72908700
# 100  *Close price adjusted for splits.**Adjusted cl...
#
# [101 rows x 7 columns]

# %%
history_price_df =history_price_df.iloc[:3]
history_price_df
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Jan 31, 2020  327.00  327.17  320.73  321.73      321.73  113688600
# 1  Jan 30, 2020  324.36  327.91  323.54  327.68      327.68   75491800
# 2  Jan 29, 2020  328.38  328.63  326.40  326.62      326.62   53888900

# %%
Options_df = pd.read_html('https://finance.yahoo.com/quote/SPY/options?p=SPY')[0]
Options_df.head()
# Out:
#         Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 0  SPY200203C00270000   2020-01-31 3:46PM EST   270.0       51.70  52.15
# 1  SPY200203C00275000  2020-01-03 12:36PM EST   275.0       49.01  47.15
# 2  SPY200203C00280000  2020-01-06 12:03PM EST   280.0       42.76  42.16
# 3  SPY200203C00285000  2020-01-06 12:01PM EST   285.0       37.82  37.17
# 4  SPY200203C00290000   2020-01-31 3:39PM EST   290.0       31.18  32.19
#
#      Ask  Change % Change Volume Open Interest Implied Volatility
# 0  52.42  -10.11  -16.36%     80             0            112.94%
# 1  47.42    0.00        -      2             0            103.13%
# 2  42.43    0.00        -      -             0             93.75%
# 3  37.43    0.00        -      -             0             84.18%
# 4  32.44   -5.81  -15.71%      1             0             74.80%

# %%
Options_df.dtypes
# Out:
# Contract Name          object
# Last Trade Date        object
# Strike                float64
# Last Price            float64
# Bid                    object
# Ask                   float64
# Change                float64
# % Change               object
# Volume                 object
# Open Interest          object
# Implied Volatility     object
# dtype: object

# %%
Options_df['Last Trade Date'] = Options_df['Last Trade Date'].map(lambda x:x.split(' ')[0])

# %%
Options_df = Options_df.rename(columns={"Last Trade Date": "Date"})
Options_df = Options_df.sort_values(by='Date', ascending=False)

Options_df['Date'] = pd.to_datetime(Options_df['Date'])
begin_date = '2020-01-27'
Options_df = Options_df.loc[(Options_df['Date'] >= begin_date)]
Options_df
# Out:
#          Contract Name       Date  Strike  Last Price    Bid    Ask  Change  \
# 0   SPY200203C00270000 2020-01-31   270.0       51.70  52.15  52.42  -10.11
# 23  SPY200203C00322000 2020-01-31   322.0        2.20   2.16   2.21   -3.61
# 25  SPY200203C00324000 2020-01-31   324.0        1.10   1.06   1.10   -3.52
# 26  SPY200203C00325000 2020-01-31   325.0        0.69   0.66   0.69   -3.10
# 27  SPY200203C00326000 2020-01-31   326.0        0.39   0.38   0.39   -2.82
# 28  SPY200203C00327000 2020-01-31   327.0        0.20   0.20   0.22   -2.23
# 30  SPY200203C00328000 2020-01-31   328.0        0.11   0.10   0.12   -1.63
# 31  SPY200203C00328500 2020-01-31   328.5        0.08   0.06   0.08   -1.41
# 32  SPY200203C00329000 2020-01-31   329.0        0.05   0.05   0.06   -1.15
# 33  SPY200203C00329500 2020-01-31   329.5        0.03   0.03   0.04   -0.91
# 34  SPY200203C00330000 2020-01-31   330.0        0.02   0.02   0.03   -0.72
# 35  SPY200203C00330500 2020-01-31   330.5        0.02   0.01   0.02   -0.54
# 36  SPY200203C00331000 2020-01-31   331.0        0.01   0.00   0.01   -0.40
# 37  SPY200203C00331500 2020-01-31   331.5        0.01   0.00   0.01   -0.28
# 38  SPY200203C00332000 2020-01-31   332.0        0.02   0.01   0.02   -0.19
# 39  SPY200203C00332500 2020-01-31   332.5        0.01   0.00   0.01   -0.12
# 40  SPY200203C00333000 2020-01-31   333.0        0.01   0.01   0.02   -0.08
# 41  SPY200203C00333500 2020-01-31   333.5        0.01   0.00   0.01   -0.04
# 42  SPY200203C00334000 2020-01-31   334.0        0.01   0.00   0.01   -0.02
# 44  SPY200203C00335000 2020-01-31   335.0        0.01   0.02   0.01    0.00
# 45  SPY200203C00336000 2020-01-31   336.0        0.01   0.00   0.01   -0.01
# 24  SPY200203C00323000 2020-01-31   323.0        1.59   1.57   1.62   -3.75
# 29  SPY200203C00327500 2020-01-31   327.5        0.15   0.15   0.16   -1.93
# 22  SPY200203C00321000 2020-01-31   321.0        2.81   2.82   2.89   -4.87
# 20  -37.48%   1030             0             24.20%
# 19  -42.46%    990             0             25.54%
# 18  -29.95%    325             0             26.98%
# 17  -38.69%    146             0             28.37%
# 16  -27.41%    280             0             29.79%
# 15  -16.13%    196             0             32.11%
# 13  -36.17%     89             0             35.74%
# 12  -22.07%     64             0             37.40%
# 11  -32.63%     68             0             39.43%
# 4   -15.71%      1             0             74.80%
# 21  -55.01%   6286             0             22.86%
# 6   -29.18%      8             0             55.96%
# 7    -7.58%      2             0             52.34%
# 46        -     21             0             19.92%
# 43  -50.00%     88             0             17.19%
# 5    -9.64%      -             -             63.53%
# 14  -18.25%     27             0             33.96%
# 47        -    236             0             21.09%
# 51        -      1             0             25.78%
# 8   -10.85%      1             0             49.07%
# 48        -     37             0             22.27%
# 49        -    117             0             23.44%
# 10  -18.34%     45             0             41.41%

# %%
historical_price_df = pd.read_csv('SPY.csv')
historical_price_df = historical_price_df.sort_values(by='Date', ascending=False)
historical_price_df['Date'] = pd.to_datetime(historical_price_df['Date'])
most_one_week_df = historical_price_df.loc[(historical_price_df['Date'] >= begin_date)]
most_one_week_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 251 2020-01-28  325.059998  327.839996  323.603790  326.880005  326.880005
# 250 2020-01-27  323.029999  325.119995  322.660004  323.500000  323.500000
#
#        Volume
# 251  63833953
# 250  83877900

# %%
Stock_Option_df = pd.merge(Options_df, most_one_week_df, on='Date', how='left')

# %%
Stock_Option_df
# Out:
#          Contract Name       Date  Strike  Last Price    Bid    Ask  Change  \
# 0   SPY200203C00270000 2020-01-31   270.0       51.70  52.15  52.42  -10.11
# 1   SPY200203C00322000 2020-01-31   322.0        2.20   2.16   2.21   -3.61
# 2   SPY200203C00324000 2020-01-31   324.0        1.10   1.06   1.10   -3.52
# 3   SPY200203C00325000 2020-01-31   325.0        0.69   0.66   0.69   -3.10
# 4   SPY200203C00326000 2020-01-31   326.0        0.39   0.38   0.39   -2.82
# 5   SPY200203C00327000 2020-01-31   327.0        0.20   0.20   0.22   -2.23
# 6   SPY200203C00328000 2020-01-31   328.0        0.11   0.10   0.12   -1.63
# 7   SPY200203C00328500 2020-01-31   328.5        0.08   0.06   0.08   -1.41
# 8   SPY200203C00329000 2020-01-31   329.0        0.05   0.05   0.06   -1.15
# 9   SPY200203C00329500 2020-01-31   329.5        0.03   0.03   0.04   -0.91
# 10  SPY200203C00330000 2020-01-31   330.0        0.02   0.02   0.03   -0.72
# 11  SPY200203C00330500 2020-01-31   330.5        0.02   0.01   0.02   -0.54
# 12  SPY200203C00331000 2020-01-31   331.0        0.01   0.00   0.01   -0.40
# 13  SPY200203C00331500 2020-01-31   331.5        0.01   0.00   0.01   -0.28
# 14  SPY200203C00332000 2020-01-31   332.0        0.02   0.01   0.02   -0.19
# 15  SPY200203C00332500 2020-01-31   332.5        0.01   0.00   0.01   -0.12
# 16  SPY200203C00333000 2020-01-31   333.0        0.01   0.01   0.02   -0.08
# 6   -93.68%    15987             0             14.11%         NaN         NaN
# 7   -94.63%     9538             0             13.72%         NaN         NaN
# 8   -95.83%     9625             0             13.77%         NaN         NaN
# 9   -96.81%     3295             0             13.58%         NaN         NaN
# 10  -97.30%    14216             0             13.67%         NaN         NaN
# 11  -96.43%     1351             0             13.48%         NaN         NaN
# 12  -97.56%     3522             0             12.89%         NaN         NaN
# 13  -96.55%     3338             0             13.67%         NaN         NaN
# 14  -90.48%     1903             0             15.43%         NaN         NaN
# 15  -92.31%     1144             0             14.84%         NaN         NaN
# 16  -88.89%     2137             0             16.80%         NaN         NaN
# 17  -80.00%     3853             0             16.02%         NaN         NaN
# 18  -66.67%      297             0             16.41%         NaN         NaN
# 19        -       34             0             17.58%         NaN         NaN
# 20  -50.00%       15             0             18.75%         NaN         NaN
# 21  -70.22%    27483             0             18.78%         NaN         NaN
# 22  -92.79%     6256             0             14.16%         NaN         NaN
# 23  -63.41%     5805             0             21.49%         NaN         NaN
# 24  -37.48%     1030             0             24.20%         NaN         NaN
# 25  -42.46%      990             0             25.54%         NaN         NaN
# 26  -29.95%      325             0             26.98%         NaN         NaN
# 27  -38.69%      146             0             28.37%         NaN         NaN
# 28  -27.41%      280             0             29.79%         NaN         NaN
# 29  -16.13%      196             0             32.11%         NaN         NaN
# 30  -36.17%       89             0             35.74%         NaN         NaN
# 31  -22.07%       64             0             37.40%         NaN         NaN
# 32  -32.63%       68             0             39.43%         NaN         NaN
# 33  -15.71%        1             0             74.80%         NaN         NaN
# 34  -55.01%     6286             0             22.86%         NaN         NaN
# 35  -29.18%        8             0             55.96%         NaN         NaN
# 36   -7.58%        2             0             52.34%         NaN         NaN
# 37        -       21             0             19.92%         NaN         NaN
# 38  -50.00%       88             0             17.19%         NaN         NaN
# 39   -9.64%        -             -             63.53%         NaN         NaN
# 40  -18.25%       27             0             33.96%         NaN         NaN
# 41        -      236             0             21.09%         NaN         NaN
# 42        -        1             0             25.78%         NaN         NaN
# 43  -10.85%        1             0             49.07%  325.059998  327.839996
# 44        -       37             0             22.27%  325.059998  327.839996
# 45        -      117             0             23.44%  325.059998  327.839996
# 46  -18.34%       45             0             41.41%  323.029999  325.119995
#
#            Low       Close   Adj Close    Volume_y
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN
# 41         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN
# 43  323.603790  326.880005  326.880005  63833953.0
# 44  323.603790  326.880005  326.880005  63833953.0
# 45  323.603790  326.880005  326.880005  63833953.0
# 46  322.660004  323.500000  323.500000  83877900.0

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
import psycopg2 
import io

# %%
# Path to SQL_PGADMIN
#database_path = "http://localhost:5432/stockoptions"
# .   Connects!
#engine = create_engine('postgresql://postgres:yzp911107@localhost:5432/',pool_size=20,max_overflow=-1)
#connection = engine.connect()
#conn = engine.connect()

# %%
# Path to SQlAdmin
database_path = "http://localhost:5432/SPY"

# %%
# .  does connect
engine = create_engine('postgresql://postgres:Roshan2017@localhost:5432/SPY',pool_size=20,max_overflow=-1)
#connection = engine.connect()
conn = engine.connect()
# https://martin-thoma.com/configuration-files-in-python/

# %%
Stock_Option_sql = Stock_Option_df.rename(columns={"Contract Name":"ContractName",
                                               "Last Price":"LastPrice",
                                               "% Change":"PercentChange",
                                               "Open Interest":"OpenInterest",
                                               "Implied Volatility":"ImpliedVolatility",
                                               "Adj Close":"AdjClose",
                                                  "Open":"OpenPrice",
                                                  "Close":"ClosePrice"})

# %%
Stock_Option_sql.head()
# Out:
#          ContractName       Date  Strike  LastPrice    Bid    Ask  Change  \
# 0  SPY200203C00270000 2020-01-31   270.0      51.70  52.15  52.42  -10.11
# 1  SPY200203C00322000 2020-01-31   322.0       2.20   2.16   2.21   -3.61
# 2  SPY200203C00324000 2020-01-31   324.0       1.10   1.06   1.10   -3.52
# 3  SPY200203C00325000 2020-01-31   325.0       0.69   0.66   0.69   -3.10
# 4  SPY200203C00326000 2020-01-31   326.0       0.39   0.38   0.39   -2.82
#
#   PercentChange Volume_x OpenInterest ImpliedVolatility  OpenPrice  High  Low  \
# 0       -16.36%       80            0           112.94%        NaN   NaN  NaN
# 1       -62.13%    17278            0            20.04%        NaN   NaN  NaN
# 2       -76.19%    49374            0            17.38%        NaN   NaN  NaN
# 3       -81.79%    46029            0            16.13%        NaN   NaN  NaN
# 4       -87.85%    43170            0            14.97%        NaN   NaN  NaN
#
#    ClosePrice  AdjClose  Volume_y
# 0         NaN       NaN       NaN
# 1         NaN       NaN       NaN
# 2         NaN       NaN       NaN
# 3         NaN       NaN       NaN
# 4         NaN       NaN       NaN

# %%
session = Session(bind=engine)

# %%
#session.add(Stock_Option_sql)

# %%
Stock_Option_sql.to_sql(name="contracts", con=engine, if_exists="replace", index=False)

# %%
# The above parameters can be "Replace", "Append" and "Fail"!
